# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('ggplot')

# %%
df=pd.read_csv('train_loan.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                  0         NaN               360
# 1             4583               1508         128               360
# 2             3000                  0          66               360
# 3             2583               2358         120               360
# 4             6000                  0         141               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# 2               1         Urban           Y
# 3               1         Urban           Y
# 4               1         Urban           Y

# %%
df.keys()
# Out:
# Index([u'Loan_ID', u'Gender', u'Married', u'Dependents', u'Education', u'Self_Employed', u'ApplicantIncome', u'CoapplicantIncome', u'LoanAmount', u'Loan_Amount_Term', u'Credit_History', u'Property_Area', u'Loan_Status'], dtype='object')

# %%
df=df.dropna()

# %%
code={'N':0,'Y':1}
for k,i in df.iterrows():
    if i['Loan_Status']==i['Loan_Status']:
        df.loc[k,"Loan_Status"]=code[i['Loan_Status']]

# %%
code={'Female':0,'Male':1}
for k,i in df.iterrows():
    df.loc[k,"Gender"]=code[i['Gender']]

# %%
code={'No':0,'Yes':1}
for k,i in df.iterrows():
    df.loc[k,"Self_Employed"]=code[i['Self_Employed']]

# %%
code={'Not Graduate':0,'Graduate':1}
for k,i in df.iterrows():
    df.loc[k,"Education"]=code[i['Education']]

# %%
code={'No':0,'Yes':1}
for k,i in df.iterrows():
    df.loc[k,"Married"]=code[i['Married']]

# %%
code={'Urban':2,'Semiurban':1,'Rural':0}
for k,i in df.iterrows():
    df.loc[k,"Property_Area"]=code[i['Property_Area']]

# %%
df.loc[df.Dependents == '3+', ['Dependents']] = 3

# %%
df
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 1    LP001003      1       1          1         1             0
# 2    LP001005      1       1          0         1             1
# 3    LP001006      1       1          0         0             0
# 4    LP001008      1       0          0         1             0
# 5    LP001011      1       1          2         1             1
# 6    LP001013      1       1          0         0             0
# 7    LP001014      1       1          3         1             0
# 8    LP001018      1       1          2         1             0
# 9    LP001020      1       1          1         1             0
# 10   LP001024      1       1          2         1             0
# 12   LP001028      1       1          2         1             0
# 13   LP001029      1       0          0         1             0
# 14   LP001030      1       1          2         1             0
# 15   LP001032      1       0          0         1             0
# 17   LP001036      0       0          0         1             0
# 18   LP001038      1       1          0         0             0
# 20   LP001043      1       1          0         0             0
# 21   LP001046      1       1          1         1             0
# 22   LP001047      1       1          0         0             0
# 25   LP001066      1       1          0         1             1
# 26   LP001068      1       1          0         1             0
# 27   LP001073      1       1          2         0             0
# 28   LP001086      1       0          0         0             0
# 31   LP001095      1       0          0         1             0
# 32   LP001097      1       0          1         1             1
# 33   LP001098      1       1          0         1             0
# 34   LP001100      1       0          3         1             0
# 37   LP001112      0       1          0         1             0
# 38   LP001114      1       0          0         1             0
# 39   LP001116      1       0          0         0             0
# ..        ...    ...     ...        ...       ...           ...
# 575  LP002868      1       1          2         1             0
# 577  LP002874      1       0          0         1             0
# 578  LP002877      1       1          1         1             0
# 580  LP002892      1       1          2         1             0
# 581  LP002893      1       0          0         1             0
# %%
import numpy as np
A=df2.as_matrix([df2.columns[:]])
X=df2.as_matrix([df2.columns[[6,7]]])

# %%
# X[:,1]=np.log(X[:,1]+100)

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps=1.5, min_samples=20).fit(X)

# %%
db.labels_.max()
# Out:
# -1

# %%
ax=plt.figure(figsize=(15,10))
# plt.rcParams['figure.figsize'] = (12,9)
plt.xlabel("CoapplicantIncome")
plt.ylabel("LoanAmount(k)")
plt.title("Loan")
# plt.yscale('log')
color_list=['r','g','b','c','m','y','k']
for i in xrange( -1,db.labels_.max()+10 ):
    is_loan=(A[:,11]==1) & (db.labels_==i)
    plt.scatter(X[is_loan,0], X[is_loan,1], marker='o',color='r')
    


    
    is_not_loan=(A[:,0]==0) & (db.labels_==i)
    plt.scatter(X[is_not_loan,0], X[is_not_loan,1], marker='x',color='b')

# %% [markdown]
# #co appilication and Loan amount

# %%
X=df2.as_matrix([df2.columns[[7,8]]])
A=df2.as_matrix([df2.columns[:]])

db = DBSCAN(eps=1.5, min_samples=20).fit(X)

ax=plt.figure(figsize=(15,10))
plt.xlabel("loan amount")
plt.ylabel("Loan amount term")
plt.title("Loan")
# plt.yscale('log')
color_list=['r','g','b','c','m','y','k']
for i in xrange( -1,db.labels_.max()+10 ):
    is_loan=(A[:,11]==1) & (db.labels_==i)
    plt.scatter(X[is_loan,0], X[is_loan,1], marker='o',color='r')
    


    
    is_not_loan=(A[:,0]==0) & (db.labels_==i)
    plt.scatter(X[is_not_loan,0], X[is_not_loan,1], marker='x',color='b')

# %% [markdown]
# #Loan amount and Loan amount term

# %%
X=df2.as_matrix([df2.columns[[5,7]]])
A=df2.as_matrix([df2.columns[:]])

db = DBSCAN(eps=1.5, min_samples=20).fit(X)

ax=plt.figure(figsize=(15,10))
plt.xlabel("Income")
plt.ylabel("Loan amount")
plt.title("Loan")
# plt.yscale('log')
color_list=['r','g','b','c','m','y','k']
for i in xrange( -1,db.labels_.max()+10 ):
    is_loan=(A[:,11]==1) & (db.labels_==i)
    plt.scatter(X[is_loan,0], X[is_loan,1], marker='o',color='r')
    


    
    is_not_loan=(A[:,0]==0) & (db.labels_==i)
    plt.scatter(X[is_not_loan,0], X[is_not_loan,1], marker='x',color='b')

# %% [markdown]
# #Income and Loan amount

# %%
X=df2.as_matrix([df2.columns[[4,5]]])
A=df2.as_matrix([df2.columns[:]])

db = DBSCAN(eps=1.5, min_samples=20).fit(X)

ax=plt.figure(figsize=(15,10))
plt.xlabel("Self employee")
plt.ylabel("incom")
plt.title("Loan")
# plt.yscale('log')
color_list=['r','g','b','c','m','y','k']
for i in xrange( -1,db.labels_.max()+10 ):
    is_loan=(A[:,11]==1) & (db.labels_==i)
    plt.scatter(X[is_loan,0], X[is_loan,1], marker='o',color='r')
    


    
    is_not_loan=(A[:,0]==0) & (db.labels_==i)
    plt.scatter(X[is_not_loan,0], X[is_not_loan,1], marker='x',color='b')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-b65ec8eb8372> in <module>()
#      12 for i in xrange( -1,db.labels_.max()+10 ):
#      13     is_loan=(A[:,11]==1) & (db.labels_==i)
# ---> 14     plt.scatter(X[is_loan,0], X[is_loan,1], marker='o',color='r')
#      15
#      16
#
# C:\Users\ta\Anaconda\lib\site-packages\matplotlib\pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, hold, **kwargs)
#    3198         ret = ax.scatter(x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3199                          vmin=vmin, vmax=vmax, alpha=alpha,
# -> 3200                          linewidths=linewidths, verts=verts, **kwargs)
#    3201         draw_if_interactive()
#    3202     finally:
#
# C:\Users\ta\Anaconda\lib\site-packages\matplotlib\axes\_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
#    3599                 c = np.ma.ravel(c)
#    3600
# -> 3601         x, y, s, c = cbook.delete_masked_points(x, y, s, c)
#    3602
#    3603         scales = s   # Renamed for readability below.
#
# C:\Users\ta\Anaconda\lib\site-packages\matplotlib\cbook.pyc in delete_masked_points(*args)
#    1811         return ()
#    1812     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1813         raise ValueError("First argument must be a sequence")
#    1814     nrecs = len(args[0])
#    1815     margs = []
#
# ValueError: First argument must be a sequence

# %%
X=df2.as_matrix([df2.columns[[5,8]]])
A=df2.as_matrix([df2.columns[:]])

db = DBSCAN(eps=1.5, min_samples=20).fit(X)

ax=plt.figure(figsize=(15,10))
plt.xlabel("income")
plt.ylabel("loan amount term")
plt.title("Loan")
# plt.yscale('log')
color_list=['r','g','b','c','m','y','k']
for i in xrange( -1,db.labels_.max()+10 ):
    is_loan=(A[:,11]==1) & (db.labels_==i)
    plt.scatter(X[is_loan,0], X[is_loan,1], marker='o',color='r')
    


    
    is_not_loan=(A[:,0]==0) & (db.labels_==i)
    plt.scatter(X[is_not_loan,0], X[is_not_loan,1], marker='x',color='b')

# %%
X=df2.as_matrix([df2.columns[[9,5]]])
A=df2.as_matrix([df2.columns[:]])

db = DBSCAN(eps=1.5, min_samples=20).fit(X)

ax=plt.figure(figsize=(15,10))
plt.xlabel("credit history")
plt.ylabel("income")
plt.title("Loan")
# plt.yscale('log')
color_list=['r','g','b','c','m','y','k']
for i in xrange( -1,db.labels_.max()+10 ):
    is_loan=(A[:,11]==1) & (db.labels_==i)
    plt.scatter(X[is_loan,0], X[is_loan,1], marker='o',color='r')
    


    
    is_not_loan=(A[:,0]==0) & (db.labels_==i)
    plt.scatter(X[is_not_loan,0], X[is_not_loan,1], marker='x',color='b')

# %%
X=df2.as_matrix([df2.columns[[0,5]]])
A=df2.as_matrix([df2.columns[:]])

db = DBSCAN(eps=2.0, min_samples=1000).fit(X)
db.labels_.max()
# Out:
# -1

# %%
df2.as_matrix([df2.columns[[0,5]]])
# Out:
# array([[1, 4583L],
#        [1, 3000L],
#        [1, 2583L],
#        [1, 6000L],
#        [1, 5417L],
#        [1, 2333L],
#        [1, 3036L],
#        [1, 4006L],
#        [1, 12841L],
#        [1, 3200L],
#        [1, 3073L],
#        [1, 1853L],
#        [1, 1299L],
#        [1, 4950L],
#        [0, 3510L],
#        [1, 4887L],
#        [1, 7660L],
#        [1, 5955L],
#        [1, 2600L],
#        [1, 9560L],
#        [1, 2799L],
#        [1, 4226L],
#        [1, 1442L],
#        [1, 3167L],
#        [1, 4692L],
#        [1, 3500L],
#        [1, 12500L],
#        [0, 3667L],
#        [1, 4166L],
#        [1, 3748L],
#        [1, 3600L],
#        [1, 1800L],
#        [1, 3941L],
#        [1, 5649L],
#        [1, 5821L],
#        [0, 2645L],
#        [0, 4000L],
#        [0, 1928L],
#        [0, 3086L],
#        [0, 4230L],
#        [1, 4616L],
#        [0, 11500L],
#        [1, 2708L],
#        [1, 2132L],
#        [1, 3366L],
#        [1, 8080L],
#        [1, 3357L],
#        [1, 2500L],
#        [1, 3029L],
#        [1, 2609L],
#        [0, 4166L],
#        [1, 5726L],
#        [1, 3200L],
#        [1, 10750L],
#        [1, 7100L],
#        [0, 4300L],
#        [1, 3208L],
#        [1, 1875L],
#        [1, 3500L],
#        [1, 5266L],
#        [1, 3750L],
#        [1, 3750L],
#        [1, 1000L],
#        [1, 3167L],
#        [0, 3846L],
#        [0, 1378L],
#        [1, 3988L],
#        [1, 2366L],
#        [1, 2500L],
#        [1, 8566L],
#        [1, 5695L],
#        [1, 2958L],
#        [1, 6250L],
#        [1, 3273L],
#        [1, 4133L],
#        [1, 3620L],
#        [0, 2484L],
#        [1, 1977L],
#        [1, 4188L],
#        [1, 1759L],
#        [1, 4288L],
#        [1, 4843L],
#        [1, 3052L],
#        [1, 11417L],
#        [1, 3800L],
#        [1, 2071L],
#        [1, 5316L],
#        [1, 14583L],
#        [0, 3167L],
#        [1, 5568L],
#        [0, 10408L],
#        [0, 4166L],
#        [0, 2137L],
#        [1, 2957L],
#        [1, 4300L],
#        [1, 10513L],
#        [1, 2014L],
#        [1, 2718L],
#        [1, 3459L],
#        [1, 4895L],
#        [1, 4000L],
#        [0, 4583L],
#        [1, 3316L],
#        [1, 14999L],
#        [1, 4200L],
#        [1, 5042L],
#        [1, 5417L],
#        [1, 6950L],
#        [1, 2698L],
#        [1, 11757L],
#        [0, 2330L],
#        [0, 14866L],
#        [1, 1538L],
#        [0, 10000L],
#        [1, 4860L],
#        [1, 6277L],
#        [1, 2577L],
#        [1, 9166L],
#        [1, 2281L],
#        [1, 3254L],
#        [1, 39999L],
#        [1, 9538L],
#        [1, 4583L],
#        [1, 1863L],
#        [1, 7933L],
#        [1, 3089L],
#        [1, 4167L],
#        [1, 9323L],
#        [0, 4583L],
#        [1, 2439L],
#        [1, 2237L],
#        [1, 8000L],
#        [1, 3522L],
#        [1, 5708L],
#        [1, 4344L],
#        [1, 3497L],
#        [1, 2045L],
#        [1, 5516L],
#        [1, 3750L],
#        [1, 2333L],
#        [1, 6400L],
#        [1, 4600L],
#        [1, 33846L],
#        [0, 3625L],
#        [1, 39147L],
#        [1, 2178L],
#        [1, 9328L],
#        [1, 4885L],
#        [1, 12000L],
#        [1, 6033L],
#        [1, 3858L],
#        [1, 4191L],
#        [1, 3125L],
#        [1, 8333L],
#        [1, 11000L],
#        [1, 2600L],
#        [1, 4923L],
#        [1, 3500L],
#        [1, 3917L],
#        [0, 4408L],
#        [0, 3244L],
#        [1, 3975L],
#        [1, 2479L],
#        [1, 3418L],
#        [0, 10000L],
#        [1, 3430L],
#        [1, 7787L],
#        [1, 5703L],
#        [1, 3173L],
#        [1, 3850L],
#        [1, 150L],
#        [1, 3727L],
#        [1, 2221L],
#        [1, 4009L],
#        [1, 2971L],
#        [1, 6250L],
#        [1, 3250L],
#        [1, 6250L],
#        [1, 6400L],
#        [1, 2491L],
#        [0, 8333L],
#        [1, 3155L],
#        [1, 5500L],
#        [0, 3812L],
#        [1, 3315L],
#        [1, 5819L],
#        [1, 2510L],
#        [1, 2965L],
#        [1, 6250L],
#        [1, 3406L],
#        [1, 6050L],
#        [1, 9703L],
#        [1, 6608L],
#        [1, 2882L],
#        [1, 1809L],
#        [1, 1668L],
#        [0, 3427L],
#        [1, 2583L],
#        [1, 2661L],
#        [1, 16250L],
#        [0, 3083L],
#        [1, 6045L],
#        [1, 5250L],
#        [1, 14683L],
#        [1, 2060L],
#        [0, 3481L],
#        [0, 7200L],
#        [1, 5166L],
#        [1, 4095L],
#        [1, 4708L],
#        [1, 4333L],
#        [0, 2876L],
#        [0, 3237L],
#        [1, 11146L],
#        [1, 2833L],
#        [1, 2620L],
#        [1, 3900L],
#        [1, 2750L],
#        [1, 3993L],
#        [1, 3103L],
#        [1, 14583L],
#        [1, 4053L],
#        [1, 3927L],
#        [1, 2301L],
#        [0, 1811L],
#        [1, 3158L],
#        [0, 2600L],
#        [1, 3704L],
#        [0, 4124L],
#        [1, 9508L],
#        [1, 3075L],
#        [1, 4400L],
#        [1, 3153L],
#        [1, 2383L],
#        [1, 6875L],
#        [0, 4666L],
#        [0, 5000L],
#        [1, 2014L],
#        [1, 1800L],
#        [0, 5000L],
#        [1, 1625L],
#        [1, 4000L],
#        [0, 3762L],
#        [0, 2400L],
#        [1, 20233L],
#        [0, 2917L],
#        [1, 2927L],
#        [0, 2507L],
#        [1, 3399L],
#        [1, 3717L],
#        [1, 10000L],
#        [1, 2400L],
#        [1, 4342L],
#        [1, 15000L],
#        [1, 8666L],
#        [1, 4917L],
#        [1, 5818L],
#        [0, 4333L],
#        [0, 2500L],
#        [1, 4384L],
#        [1, 2935L],
#        [1, 2500L],
#        [0, 4160L],
#        [1, 2647L],
#        [0, 2378L],
#        [1, 4554L],
#        [1, 3173L],
#        [1, 2499L],
#        [1, 3083L],
#        [1, 2625L],
#        [1, 9083L],
#        [1, 8750L],
#        [1, 2666L],
#        [0, 5500L],
#        [0, 2423L],
#        [1, 8333L],
#        [1, 3875L],
#        [1, 3000L],
#        [1, 5167L],
#        [0, 4723L],
#        [1, 5000L],
#        [1, 4750L],
#        [1, 6822L],
#        [1, 6216L],
#        [1, 2500L],
#        [1, 6325L],
#        [1, 19730L],
#        [0, 15759L],
#        [1, 5185L],
#        [1, 9323L],
#        [1, 3062L],
#        [1, 4817L],
#        [1, 8750L],
#        [1, 3069L],
#        [1, 5391L],
#        [1, 5941L],
#        [0, 6000L],
#        [1, 7167L],
#        [1, 4566L],
#        [1, 2346L],
#        [1, 2333L],
#        [1, 5488L],
#        [1, 9167L],
#        [1, 9504L],
#        [1, 1993L],
#        [1, 3100L],
#        [0, 3180L],
#        [1, 3033L],
#        [1, 3902L],
#        [0, 1500L],
#        [1, 2889L],
#        [1, 2755L],
#        [1, 2500L],
#        [0, 1963L],
#        [0, 7441L],
#        [0, 4547L],
#        [1, 2167L],
#        [0, 2213L],
#        [1, 8300L],
#        [1, 81000L],
#        [0, 3867L],
#        [1, 6096L],
#        [1, 2253L],
#        [0, 2149L],
#        [0, 2995L],
#        [0, 2600L],
#        [1, 1600L],
#        [1, 1025L],
#        [1, 3246L],
#        [1, 5829L],
#        [1, 1820L],
#        [1, 14880L],
#        [1, 2666L],
#        [0, 4606L],
#        [1, 5935L],
#        [1, 2920L],
#        [1, 2717L],
#        [0, 8624L],
#        [1, 6500L],
#        [1, 2425L],
#        [1, 3750L],
#        [1, 1926L],
#        [1, 10416L],
#        [0, 7142L],
#        [1, 3660L],
#        [1, 7901L],
#        [1, 4707L],
#        [1, 37719L],
#        [1, 3466L],
#        [1, 4652L],
#        [1, 3340L],
#        [1, 2309L],
#        [1, 3948L],
#        [1, 2483L],
#        [1, 7085L],
#        [1, 3859L],
#        [1, 4301L],
#        [1, 3708L],
#        [1, 4354L],
#        [1, 8334L],
#        [1, 7740L],
#        [1, 3015L],
#        [1, 4166L],
#        [1, 6000L],
#        [1, 2947L],
#        [1, 4333L],
#        [1, 3450L],
#        [1, 2653L],
#        [1, 4691L],
#        [1, 5532L],
#        [1, 16525L],
#        [1, 6700L],
#        [1, 16667L],
#        [0, 4350L],
#        [1, 3095L],
#        [1, 2083L],
#        [1, 10833L],
#        [1, 8333L],
#        [1, 1958L],
#        [1, 3547L],
#        [1, 18333L],
#        [1, 4583L],
#        [1, 2435L],
#        [1, 3691L],
#        [0, 17263L],
#        [1, 3597L],
#        [0, 3326L],
#        [1, 2600L],
#        [1, 2895L],
#        [1, 6283L],
#        [0, 645L],
#        [0, 3159L],
#        [1, 4865L],
#        [1, 3814L],
#        [1, 3510L],
#        [1, 2479L],
#        [0, 13262L],
#        [1, 3598L],
#        [1, 6065L],
#        [1, 3283L],
#        [1, 2130L],
#        [1, 5815L],
#        [1, 3466L],
#        [0, 2031L],
#        [1, 4683L],
#        [0, 3400L],
#        [1, 2192L],
#        [1, 2500L],
#        [1, 5677L],
#        [1, 7948L],
#        [1, 17500L],
#        [1, 3775L],
#        [1, 5285L],
#        [1, 2679L],
#        [1, 6783L],
#        [1, 4281L],
#        [1, 3588L],
#        [0, 18165L],
#        [1, 6133L],
#        [1, 3617L],
#        [1, 2917L],
#        [1, 6417L],
#        [0, 4608L],
#        [0, 2138L],
#        [1, 2239L],
#        [1, 2768L],
#        [1, 3358L],
#        [1, 2526L],
#        [0, 5000L],
#        [1, 2785L],
#        [1, 3333L],
#        [1, 2454L],
#        [1, 3593L],
#        [1, 5468L],
#        [1, 10139L],
#        [1, 3887L],
#        [0, 4180L],
#        [1, 3675L],
#        [0, 19484L],
#        [1, 5923L],
#        [1, 5800L],
#        [1, 8799L],
#        [1, 3333L],
#        [1, 3400L],
#        [0, 2378L],
#        [1, 3166L],
#        [1, 3417L],
#        [1, 16666L],
#        [1, 6125L],
#        [1, 6406L],
#        [1, 3159L],
#        [1, 3229L],
#        [1, 1782L],
#        [1, 6540L],
#        [1, 1836L],
#        [0, 3166L],
#        [1, 2787L],
#        [1, 4283L],
#        [1, 2297L],
#        [0, 2165L],
#        [1, 2726L],
#        [1, 3000L],
#        [1, 6000L],
#        [1, 3859L],
#        [1, 16120L],
#        [1, 3833L],
#        [1, 6383L],
#        [1, 9963L],
#        [1, 5780L],
#        [1, 5703L],
#        [1, 3676L],
#        [0, 12000L],
#        [1, 3400L],
#        [1, 3987L],
#        [1, 3232L],
#        [0, 2900L],
#        [1, 4106L],
#        [1, 8072L],
#        [1, 7583L],
#        [0, 4583L]], dtype=object)

# %%
ax=plt.figure(figsize=(15,10))
plt.xlabel("gender")
plt.ylabel("income")
plt.title("Loan")
# plt.yscale('log')
color_list=['r','g','b','c','m','y','k']
for i in xrange( -1,db.labels_.max()+2 ):
    is_loan=(A[:,11]==1) & (db.labels_==i)
    plt.scatter(X[is_loan,0], X[is_loan,1], marker='o',color='r')
    


    
    is_not_loan=(A[:,0]==0) & (db.labels_==i)
    plt.scatter(X[is_not_loan,0], X[is_not_loan,1], marker='x',color='b')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-7aea7772a333> in <module>()
#       9 for i in xrange( -1,db.labels_.max()+2 ):
#      10     is_loan=(A[:,11]==1) & (db.labels_==i)
# ---> 11     plt.scatter(X[is_loan,0], X[is_loan,1], marker='o',color='r')
#      12
#      13
#
# C:\Users\ta\Anaconda\lib\site-packages\matplotlib\pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, hold, **kwargs)
#    3198         ret = ax.scatter(x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3199                          vmin=vmin, vmax=vmax, alpha=alpha,
# -> 3200                          linewidths=linewidths, verts=verts, **kwargs)
#    3201         draw_if_interactive()
#    3202     finally:
#
# C:\Users\ta\Anaconda\lib\site-packages\matplotlib\axes\_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
#    3599                 c = np.ma.ravel(c)
#    3600
# -> 3601         x, y, s, c = cbook.delete_masked_points(x, y, s, c)
#    3602
#    3603         scales = s   # Renamed for readability below.
#
# C:\Users\ta\Anaconda\lib\site-packages\matplotlib\cbook.pyc in delete_masked_points(*args)
#    1811         return ()
#    1812     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1813         raise ValueError("First argument must be a sequence")
#    1814     nrecs = len(args[0])
#    1815     margs = []
#
# ValueError: First argument must be a sequence

# %%
y.shape
# Out:
# (480L,)

# %%
x.shape
# Out:
# (480L, 12L)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.cross_validation import cross_val_score

# %%
forest = ExtraTreesClassifier(n_estimators=250,random_state=0)

# %%
cross_val_score(forest, x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-dcf31b776f5b> in <module>()
# ----> 1 cross_val_score(forest, x, y)
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1569                                               train, test, verbose, None,
#    1570                                               fit_params)
# -> 1571                       for train, test in cv)
#    1572     return np.array(scores)[:, 0]
#    1573
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\externals\joblib\parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\externals\joblib\parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\externals\joblib\_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\externals\joblib\_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1663             estimator.fit(X_train, **fit_params)
#    1664         else:
# -> 1665             estimator.fit(X_train, y_train, **fit_params)
#    1666
#    1667     except Exception as e:
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\ensemble\forest.pyc in fit(self, X, y, sample_weight)
#     269         self.n_outputs_ = y.shape[1]
#     270
# --> 271         y, expanded_class_weight = self._validate_y_class_weight(y)
#     272
#     273         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\ensemble\forest.pyc in _validate_y_class_weight(self, y)
#     455
#     456     def _validate_y_class_weight(self, y):
# --> 457         check_classification_targets(y)
#     458
#     459         y = np.copy(y)
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\utils\multiclass.pyc in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171             'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'unknown'

# %%
forest.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-0562a3f294e6> in <module>()
# ----> 1 forest.fit(x,y)
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\ensemble\forest.pyc in fit(self, X, y, sample_weight)
#     269         self.n_outputs_ = y.shape[1]
#     270
# --> 271         y, expanded_class_weight = self._validate_y_class_weight(y)
#     272
#     273         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\ensemble\forest.pyc in _validate_y_class_weight(self, y)
#     455
#     456     def _validate_y_class_weight(self, y):
# --> 457         check_classification_targets(y)
#     458
#     459         y = np.copy(y)
#
# C:\Users\ta\Anaconda\lib\site-packages\sklearn\utils\multiclass.pyc in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171             'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'unknown'
